# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn3

# Load the consolidated clonotype data
df = pd.read_csv("/home/rittika/Workprojects/iRepertoire/clonotypes_with_filenames_and_umi.csv")
import pandas as pd
from supervenn import supervenn

# # Load the consolidated clonotype data
# df = pd.read_csv("your_consolidated_clonotype_file.csv")

# Group by 'Filename' and get sets of 'Clonotype'
# This creates a dictionary: {filename: set_of_clonotypes}
filename_groups = df.groupby('Filename')['Clonotype'].apply(set).to_dict()

# Extract just the sets from the dictionary in a consistent order
sets_list = list(filename_groups.values())

# Create the supervenn plot
supervenn(sets_list, side_plots=False)
